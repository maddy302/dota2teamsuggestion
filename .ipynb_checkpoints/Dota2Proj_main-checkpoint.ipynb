# %%
import sqlite3
import logging

#c = conn.cursor()
def create_db():
    """Create a sqlite3 database in which we can store matches from the dota2 api."""
    conn = sqlite3.connect('dota2data')
    conn.execute(
    "CREATE TABLE if not exists matches\
    (\
    match_id INTEGER PRIMARY KEY,\
    start_time INTEGER NOT NULL,\
    lobby_type INTEGER NOT NULL,\
    radiant_hero_1 INTEGER NOT NULL,\
    radiant_hero_2 INTEGER NOT NULL,\
    radiant_hero_3 INTEGER NOT NULL,\
    radiant_hero_4 INTEGER NOT NULL,\
    radiant_hero_5 INTEGER NOT NULL,\
    dire_hero_1 INTEGER NOT NULL,\
    dire_hero_2 INTEGER NOT NULL,\
    dire_hero_3 INTEGER NOT NULL,\
    dire_hero_4 INTEGER NOT NULL,\
    dire_hero_5 INTEGER NOT NULL,\
    game_mode INTEGER,\
    has_leaver INTEGER,\
    duration INTEGER,\
    radiant_win INTEGER\
    )")
    conn.commit()
    conn.close()

api_key = 'CB3762621E46727A6F9FC9B72F6A9DE5'
database = 'dota2data'

logging.info("Creating database because it does not exist.")
create_db()

# %% [raw]
# Connecting to the dota 2 api to fetch the results

# %%
import dota2api
import requests
import time
import json
import sqlite3
import logging
from threading import Thread 

def match_history():
    count_history = 1
    while(count_history>=0):
        do_match_history()
        time.sleep(60)
        #print('Inside match_history')
        count_history = count_history - 1
        
def do_match_history(lobby_types=[0, 2, 5, 6, 7], skill=3, tournament_games_only=False,start_match_id_local = 4015357757):
    #start_match_id = 4015357757
    #print('inside do_match_history')
    matches = 0
    count = 100*100
    while(count>0):
        tries = 0
        while tries < 3:
            tries+=1
            try:
                result = api.get_match_history(skill = skill, min_players = 10, tournament_games_only="1" if tournament_games_only else "0", 
                                               matches_requested=100, match_id=4019850312,)
                break
            except(requests.exceptions.ConnectionError,  dota2api.src.exceptions.APIError, dota2api.src.exceptions.APITimeoutError):
                logging.warning("Api or timeout error in MatchHistory on try {}.".format(tries))
                time.sleep(30)
                continue
        if tries==3:
            return
        if result["results_remaining"] == 0:
            break
        start_at_match_id = result["matches"][-1]["match_id"] - 1
        for match in result["matches"]:
            if len(match["players"]) == 10 and match["lobby_type"] in lobby_types:
                add_match_to_db(match)
                matches += 1
        count = count - 1
    print("Added", matches, "matches.")

    
def add_match_to_db(match):
    #print('Inside add_match_to_db')
    radiant_heros = list()
    dire_heros = list()
    assert(len(match["players"])==10)
    for p in match["players"]:
        slot = p["player_slot"]
        if slot< 128:
            radiant_heros.append(p["hero_id"])
        else:
            dire_heros.append(p["hero_id"])
    assert(len(radiant_heros) == 5)
    assert(len(dire_heros) == 5)
    # Skip matches where a player didnt pick a hero
    if 0 in radiant_heros or 0 in dire_heros:
        logging.info("Skipping {} because of 0 hero.".format(match["match_id"]))
        return
    connection = sqlite3.connect(database, timeout=10)
    connection.execute("INSERT OR IGNORE INTO matches values (?,?,?,?,?,?,?,?,?,?,?,?,?,null,null,null,null)",
                       (match["match_id"], match["start_time"], match["lobby_type"]) + tuple(radiant_heros) + tuple(dire_heros))
    connection.commit()
    connection.close()

api_key = 'CB3762621E46727A6F9FC9B72F6A9DE5'
database = 'dota2data'

api = dota2api.Initialise(api_key,raw_mode=True)
#match_history_thread = Thread(target=match_history)
#match_history_thread.daemon = True
#match_details_thread = Thread(target=match_details)
#match_details_thread.daemon = True
print("Starting MatchHistory and MatchDetails threads.")
#match_history_thread.start()
#match_details_thread.start()
#match_history() Uncomment this line
# This is needed (instead of joining the threads) to respond to crl-c
#while True:
#    time.sleep(1)


# def match_details():
#     count_matches = 10
#     while(count_matches>=0):
#         do_match_details()
#         time.sleep(60)
#         print('Inside match_details')
#         count_matches = count_matches - 1
        
    
# def do_match_details():
#     print('Inside do_match_details')
#     connection = sqlite3.connect(database, timeout=10)
#     matches = connection.execute("SELECT match_id FROM matches WHERE radiant_win IS NULL").fetchall()
#     connection.close()
#     for (match_id,) in matches:
#         try:
#             result = api.get_match_details(match_id=match_id)
#         except (requests.exceptions.ConnectionError,  dota2api.src.exceptions.APIError, dota2api.src.exceptions.APITimeoutError):
#             logging.warning("Api or timeout error in MatchDetails on matchid {}.".format(match_id))
#             time.sleep(30)
#             continue
#         print("Added details for {}.".format(result["match_id"]))
#         update_match_in_db(result)
#         time.sleep(1)
    

# def update_match_in_db():
#     print('Inside update_match_in_db')
#     has_leavers = False
#     for p in match["players"]:
#         if p["leaver_status"] in [2,3,4,5,6]: 
#             has_leavers = True
#         connection = sqlite3.connect(database, timeout = 10)
#         connection.execute("UPDATE OR IGNORE matches SET game_mode=?, has_leaver=?, duration=?, radiant_win=? WHERE match_id=?", (match["game_mode"], has_leavers, match["duration"], match["radiant_win"], match["match_id"]))
#         connection.commit()
#         connection.close()
# Out:
# Starting MatchHistory and MatchDetails threads.
# ('Added', 1000000, 'matches.')
# ('Added', 1000000, 'matches.')

# %% [raw]
# Fetching the match details

# %%
def match_details():
    count_matches = 1
    while(count_matches>=0):
        do_match_details()
        time.sleep(60)
        print('Inside match_details')
        count_matches = count_matches - 1
        
    
def do_match_details():
    print('Inside do_match_details')
    connection = sqlite3.connect(database, timeout=10)
    matches = connection.execute("SELECT match_id FROM matches WHERE radiant_win IS NULL").fetchall()
    connection.close()
    for (match_id,) in matches:
        try:
            result = api.get_match_details(match_id=match_id)
        except (requests.exceptions.ConnectionError,  dota2api.src.exceptions.APIError, dota2api.src.exceptions.APITimeoutError):
            logging.warning("Api or timeout error in MatchDetails on matchid {}.".format(match_id))
            time.sleep(30)
            continue
        print("Added details for {}.".format(result["match_id"]))
        update_match_in_db(result)
        time.sleep(1)
    

def update_match_in_db(match):
#     print('Inside update_match_in_db')
    has_leavers = False
    for p in match["players"]:
        if p["leaver_status"] in [2,3,4,5,6]: 
            has_leavers = True
        connection = sqlite3.connect(database, timeout = 10)
        connection.execute("UPDATE OR IGNORE matches SET game_mode=?, has_leaver=?, duration=?, radiant_win=? WHERE match_id=?", (match["game_mode"], has_leavers, match["duration"], match["radiant_win"], match["match_id"]))
        connection.commit()
        connection.close()
        

match_details()
# Out:
# Inside do_match_details
# Added details for 4020068620.
# Added details for 4020090521.
# Added details for 4020090576.
# Added details for 4020090647.
# Added details for 4020092845.
# Added details for 4020094833.
# Added details for 4020095145.
# Added details for 4020095486.
# Added details for 4020095540.
# Added details for 4020095880.
# Added details for 4020096024.
# Added details for 4020096559.
# Added details for 4020096625.
# Added details for 4020096754.
# Added details for 4020096803.
# Added details for 4020096816.
# Added details for 4020097142.
# Added details for 4020097152.
# Added details for 4020097324.
# Added details for 4020097385.
# Added details for 4020097494.
# Added details for 4020097909.
# Added details for 4020097969.
# Added details for 4020098446.
# Added details for 4020098607.
# Added details for 4020098868.
# Added details for 4020099135.
# Added details for 4020099162.
# Added details for 4020099377.
# Added details for 4020100356.
# Added details for 4020100438.
# Added details for 4020100571.
# Added details for 4020100761.
# Added details for 4020100790.
# Added details for 4020100932.
# Added details for 4020101438.
# Added details for 4020101506.
# Added details for 4020101559.
# Added details for 4020101599.
# Added details for 4020101718.
# Added details for 4020101815.
# Added details for 4020101884.
# Added details for 4020102023.
# Added details for 4020102222.
# Added details for 4020102338.
# Added details for 4020102401.
# Added details for 4020102463.
# Added details for 4020102551.
# Added details for 4020102567.
# Added details for 4020102844.
# Added details for 4020102920.
# Added details for 4020102940.
# Added details for 4020103040.
# Added details for 4020103162.
# Added details for 4020103448.
# Added details for 4020103535.
# Added details for 4020103639.
# Added details for 4020103654.
# Added details for 4020103737.
# Added details for 4020103750.
# Added details for 4020103777.
# Added details for 4020103993.
# Added details for 4020104062.
# Added details for 4020104098.
# Added details for 4020104116.
# Added details for 4020104393.
# Added details for 4020104403.
# Added details for 4020104532.
# Added details for 4020104628.
# Added details for 4020104710.
# Added details for 4020104963.
# Added details for 4020105013.
# Added details for 4020105026.
# Added details for 4020105074.
# Added details for 4020105232.
# Added details for 4020105412.
# Added details for 4020105447.
# Added details for 4020105595.
# Added details for 4020105612.
# Added details for 4020105651.
# Added details for 4020105804.
# Added details for 4020105952.
# Added details for 4020105974.
# Added details for 4020106111.
# Added details for 4020106238.
# Added details for 4020106312.
# Added details for 4020106340.
# Added details for 4020106385.
# Added details for 4020106441.
# Added details for 4020106461.
# Added details for 4020106584.
# Added details for 4020106629.
# Added details for 4020106696.
# Added details for 4020106712.
# Added details for 4020106766.
# Added details for 4020106786.
# Added details for 4020106819.
# Added details for 4020106885.
# Added details for 4020106912.
# Added details for 4020106938.
# Added details for 4020106943.
# Added details for 4020107007.
# Added details for 4020107212.
# Added details for 4020107509.
# Added details for 4020107623.
# Added details for 4020107645.
# Added details for 4020107848.
# Added details for 4020107958.
# Added details for 4020108130.
# Added details for 4020108217.
# Added details for 4020108226.
# Added details for 4020108234.
# Added details for 4020108446.
# Added details for 4020108526.
# Added details for 4020108668.
# Added details for 4020108750.
# Added details for 4020108965.
# Added details for 4020109088.
# Added details for 4020109527.
# Added details for 4020109548.
# Added details for 4020109563.
# Added details for 4020109689.
# Added details for 4020109742.
# Added details for 4020109841.
# Added details for 4020109920.
# Added details for 4020109962.
# Added details for 4020110012.
# Added details for 4020110245.
# Added details for 4020110246.
# Added details for 4020110549.
# Added details for 4020110584.
# Added details for 4020110604.
# Added details for 4020110711.
# Added details for 4020110712.
# Added details for 4020111127.
# Added details for 4020111198.
# Added details for 4020111413.
# Added details for 4020111498.
# Added details for 4020111546.
# Added details for 4020111621.
# Added details for 4020111832.
# Added details for 4020111896.
# Added details for 4020111930.
# Added details for 4020111975.
# Added details for 4020111995.
# Added details for 4020112093.
# Added details for 4020112114.
# Added details for 4020112285.
# Added details for 4020112507.
# Added details for 4020112614.
# Added details for 4020112657.
# Added details for 4020112672.
# Added details for 4020112805.
# Added details for 4020112845.
# Added details for 4020112880.
# Added details for 4020112891.
# Added details for 4020112976.
# Added details for 4020113086.
# Added details for 4020113156.
# Added details for 4020113434.
# Added details for 4020113494.
# Added details for 4020113555.
# Added details for 4020113642.
# Added details for 4020113677.
# Added details for 4020113736.
# Added details for 4020113791.
# Added details for 4020113795.
# Added details for 4020113965.
# Added details for 4020114021.
# Added details for 4020114213.
# Added details for 4020114228.
# Added details for 4020114237.
# Added details for 4020114296.
# Added details for 4020114308.
# Added details for 4020114485.
# Added details for 4020114632.
# Added details for 4020114706.
# Added details for 4020114724.
# Added details for 4020114780.
# Added details for 4020114795.
# Added details for 4020114818.
# Added details for 4020114981.
# Added details for 4020115233.
# Added details for 4020115298.
# Added details for 4020115315.
# Added details for 4020115435.
# Added details for 4020115626.
# Added details for 4020115690.
# Added details for 4020115830.
# Added details for 4020115884.
# Added details for 4020116059.
# Added details for 4020116124.
# Added details for 4020116202.
# Added details for 4020116348.
# Added details for 4020116379.
# Added details for 4020116471.
# Added details for 4020116521.
# Added details for 4020116921.
# Added details for 4020117089.
# Added details for 4020117332.
# Added details for 4020117339.
# Added details for 4020117414.
# Added details for 4020117433.
# Added details for 4020117508.
# Added details for 4020117517.
# Added details for 4020117567.
# Added details for 4020117729.
# Added details for 4020117842.
# Added details for 4020117997.
# Added details for 4020118054.
# Added details for 4020118120.
# Added details for 4020118279.
# Added details for 4020118438.
# Added details for 4020118518.
# Added details for 4020118593.
# Added details for 4020118733.
# Added details for 4020118769.
# Added details for 4020118830.
# Added details for 4020118872.
# Added details for 4020118959.
# Added details for 4020119264.
# Added details for 4020119422.
# Added details for 4020119439.
# Added details for 4020119457.
# Added details for 4020119514.
# Added details for 4020119889.
# Added details for 4020120012.
# Added details for 4020120038.
# Added details for 4020120092.
# Added details for 4020120102.
# Added details for 4020120119.
# Added details for 4020120149.
# Added details for 4020120153.
# Added details for 4020120245.
# Added details for 4020120305.
# Added details for 4020120311.
# Added details for 4020120417.
# Added details for 4020120483.
# Added details for 4020120612.
# Added details for 4020120615.
# Added details for 4020120709.
# Added details for 4020120751.
# Added details for 4020120825.
# Added details for 4020120826.
# Added details for 4020120945.
# Added details for 4020121013.
# Added details for 4020121168.
# Added details for 4020121190.
# Added details for 4020121227.
# Added details for 4020121425.
# Added details for 4020121431.
# Added details for 4020121490.
# Added details for 4020121491.
# Added details for 4020121616.
# Added details for 4020121660.
# Added details for 4020121667.
# Added details for 4020121706.
# Added details for 4020121945.
# Added details for 4020121946.
# Added details for 4020122242.
# Added details for 4020122273.
# Added details for 4020122478.
# Added details for 4020122567.
# Added details for 4020122586.
# Added details for 4020122765.
# Added details for 4020122788.
# Added details for 4020122797.
# Added details for 4020123011.
# Added details for 4020123164.
# Added details for 4020123212.
# Added details for 4020123223.
# Added details for 4020123227.
# Added details for 4020123243.
# Added details for 4020123340.
# Added details for 4020123439.
# Added details for 4020123585.
# Added details for 4020123769.
# Added details for 4020123861.
# Added details for 4020124058.
# Added details for 4020124070.
# Added details for 4020124154.
# Added details for 4020124311.
# Added details for 4020124448.
# Added details for 4020124477.
# Added details for 4020124522.
# Added details for 4020124576.
# Added details for 4020124608.
# Added details for 4020124724.
# Added details for 4020124972.
# Added details for 4020125170.
# Added details for 4020125208.
# Added details for 4020125321.
# Added details for 4020125434.
# Added details for 4020125475.
# Added details for 4020125589.
# Added details for 4020125752.
# Added details for 4020125776.
# Added details for 4020125795.
# Added details for 4020126100.
# Added details for 4020126421.
# Added details for 4020126562.
# Added details for 4020126597.
# Added details for 4020126613.
# Added details for 4020126881.
# Added details for 4020126882.
# Added details for 4020127080.
# Added details for 4020127205.
# Added details for 4020127679.
# Added details for 4020127694.
# Added details for 4020127728.
# Added details for 4020127771.
# Added details for 4020127901.
# Added details for 4020127909.
# Added details for 4020127997.
# Added details for 4020128043.
# Added details for 4020128115.
# Added details for 4020128136.
# Added details for 4020128180.
# Added details for 4020128298.
# Added details for 4020128302.
# Added details for 4020128314.
# Added details for 4020128465.
# Added details for 4020128467.
# Added details for 4020128486.
# Added details for 4020128546.
# Added details for 4020128676.
# Added details for 4020128830.
# Added details for 4020128922.
# Added details for 4020128955.
# Added details for 4020128956.
# Added details for 4020128994.
# Added details for 4020129012.
# Added details for 4020129076.
# Added details for 4020129149.
# Added details for 4020129327.
# Added details for 4020129401.
# Added details for 4020129482.
# Added details for 4020129539.
# Added details for 4020129637.
# Added details for 4020129708.
# Added details for 4020129802.
# Added details for 4020129835.
# Added details for 4020129843.
# Added details for 4020129939.
# Added details for 4020129988.
# Added details for 4020130141.
# Added details for 4020130143.
# Added details for 4020130194.
# Added details for 4020130261.
# Added details for 4020130266.
# Added details for 4020130403.
# Added details for 4020130410.
# Added details for 4020130455.
# Added details for 4020130542.
# Added details for 4020130724.
# Added details for 4020130993.
# Added details for 4020131007.
# Added details for 4020131096.
# Added details for 4020131110.
# Added details for 4020131470.
# Added details for 4020131485.
# Added details for 4020131527.
# Added details for 4020131532.
# Added details for 4020131582.
# Added details for 4020131611.
# Added details for 4020131618.
# Added details for 4020132052.
# Added details for 4020132065.
# Added details for 4020132153.
# Added details for 4020132199.
# Added details for 4020132244.
# Added details for 4020132315.
# Added details for 4020132361.
# Added details for 4020132376.
# Added details for 4020132418.
# Added details for 4020132536.
# Added details for 4020132623.
# Added details for 4020132634.
# Added details for 4020132653.
# Added details for 4020132655.
# Added details for 4020132680.
# Added details for 4020133008.
# Added details for 4020133087.
# Added details for 4020133138.
# Added details for 4020133179.
# Added details for 4020133238.
# Added details for 4020133240.
# Added details for 4020133347.
# Added details for 4020133541.
# Added details for 4020133739.
# Added details for 4020134018.
# Added details for 4020134047.
# Added details for 4020134107.
# Added details for 4020134203.
# Added details for 4020134245.
# Added details for 4020134315.
# Added details for 4020134427.
# Added details for 4020134476.
# Added details for 4020134632.
# Added details for 4020134678.
# Added details for 4020134743.
# Added details for 4020134802.
# Added details for 4020134809.
# Added details for 4020134836.
# Added details for 4020134852.
# Added details for 4020134886.
# Added details for 4020134938.
# Added details for 4020135026.
# Added details for 4020135175.
# Added details for 4020135302.
# Added details for 4020135452.
# Added details for 4020135501.
# Added details for 4020135571.
# Added details for 4020135673.
# Added details for 4020136039.
# Added details for 4020136043.
# Added details for 4020136177.
# Added details for 4020136254.
# Added details for 4020136289.
# Added details for 4020136387.
# Added details for 4020136439.
# Added details for 4020136495.
# Added details for 4020136545.
# Added details for 4020136611.
# Added details for 4020136873.
# Added details for 4020136921.
# Added details for 4020137005.
# Added details for 4020137031.
# Added details for 4020137110.
# Added details for 4020137220.
# Added details for 4020137394.
# Added details for 4020137422.
# Added details for 4020137493.
# Added details for 4020137991.
# Added details for 4020138009.
# Added details for 4020138182.
# Added details for 4020138229.
# Added details for 4020138372.
# Added details for 4020138493.
# Added details for 4020138515.
# Added details for 4020138631.
# Added details for 4020138953.
# Added details for 4020139319.
# Added details for 4020139439.
# Added details for 4020139461.
# Added details for 4020139492.
# Added details for 4020139622.
# Added details for 4020139707.
# Added details for 4020139719.
# Added details for 4020139722.
# Added details for 4020139857.
# Added details for 4020139883.
# Added details for 4020139888.
# Added details for 4020139976.
# Added details for 4020139994.
# Added details for 4020140197.
# Added details for 4020140201.
# Added details for 4020140317.
# Added details for 4020140419.
# Added details for 4020140425.
# Added details for 4020140563.
# Added details for 4020140739.
# Added details for 4020140808.
# Added details for 4020140953.
# Added details for 4020140997.
# Added details for 4020141105.
# Added details for 4020141225.
# Added details for 4020141398.
# Added details for 4020141667.
# Added details for 4020141792.
# Added details for 4020141918.
# Added details for 4020142077.
# Added details for 4020142095.
# Added details for 4020142116.
# Added details for 4020142282.
# Added details for 4020142300.
# Added details for 4020142319.
# Added details for 4020142320.
# Added details for 4020142343.
# Added details for 4020142477.
# Added details for 4020142501.
# Added details for 4020142566.
# Added details for 4020142663.
# Added details for 4020142683.
# Added details for 4020142758.
# Added details for 4020143270.
# Added details for 4020143309.
# Added details for 4020143441.
# Added details for 4020143576.
# Added details for 4020143581.
# Added details for 4020143710.
# Added details for 4020143712.
# Added details for 4020143907.
# Added details for 4020143988.
# Added details for 4020143996.
# Added details for 4020144136.
# Added details for 4020144262.
# Added details for 4020144323.
# Added details for 4020144339.
# Added details for 4020144425.
# Added details for 4020144432.
# Added details for 4020144583.
# Added details for 4020144652.
# Added details for 4020144669.
# Added details for 4020144833.
# Added details for 4020144835.
# Added details for 4020144988.
# Added details for 4020145127.
# Added details for 4020145362.
# Added details for 4020145441.
# Added details for 4020145476.
# Added details for 4020145558.
# Added details for 4020145591.
# Added details for 4020145618.
# Added details for 4020145690.
# Added details for 4020145807.
# Added details for 4020146073.
# Added details for 4020146355.
# Added details for 4020146363.
# Added details for 4020146417.
# Added details for 4020146485.
# Added details for 4020146512.
# Added details for 4020146563.
# Added details for 4020146713.
# Added details for 4020146719.
# Added details for 4020146728.
# Added details for 4020146777.
# Added details for 4020146815.
# Added details for 4020146842.
# Added details for 4020147047.
# Added details for 4020147089.
# Added details for 4020147104.
# Added details for 4020147143.
# Added details for 4020147307.
# Added details for 4020147361.
# Added details for 4020147363.
# Added details for 4020147534.
# Added details for 4020147567.
# Added details for 4020147570.
# Added details for 4020147621.
# Added details for 4020147692.
# Added details for 4020147821.
# Added details for 4020147900.
# Added details for 4020147905.
# Added details for 4020148053.
# Added details for 4020148139.
# Added details for 4020148240.
# Added details for 4020148313.
# Added details for 4020148424.
# Added details for 4020148441.
# Added details for 4020148453.
# Added details for 4020148531.
# Added details for 4020148775.
# Added details for 4020148861.
# Added details for 4020149072.
# Added details for 4020149165.
# Added details for 4020149249.
# Added details for 4020149270.
# Added details for 4020149323.
# Added details for 4020149413.
# Added details for 4020149485.
# Added details for 4020149626.
# Added details for 4020149657.
# Added details for 4020149757.
# Added details for 4020149833.
# Added details for 4020150004.
# Added details for 4020150080.
# Added details for 4020150172.
# Added details for 4020150193.
# Added details for 4020150215.
# Added details for 4020150290.
# Added details for 4020150423.
# Added details for 4020150443.
# Added details for 4020150650.
# Added details for 4020150695.
# Added details for 4020150716.
# Added details for 4020150737.
# Added details for 4020150782.
# Added details for 4020150888.
# Added details for 4020150918.
# Added details for 4020150932.
# Added details for 4020150936.
# Added details for 4020151087.
# Added details for 4020151246.
# Added details for 4020151355.
# Added details for 4020151483.
# Added details for 4020151648.
# Added details for 4020151738.
# Added details for 4020151788.
# Added details for 4020151792.
# Added details for 4020151831.
# Added details for 4020151894.
# Added details for 4020151902.
# Added details for 4020152181.
# Added details for 4020152257.
# Added details for 4020152267.
# Added details for 4020152270.
# Added details for 4020152336.
# Added details for 4020152357.
# Added details for 4020152424.
# Added details for 4020152468.
# Added details for 4020152502.
# Added details for 4020152799.
# Added details for 4020152805.
# Added details for 4020152860.
# Added details for 4020152948.
# Added details for 4020153005.
# Added details for 4020153031.
# Added details for 4020153352.
# Added details for 4020153658.
# Added details for 4020153894.
# Added details for 4020154027.
# Added details for 4020154127.
# Added details for 4020154304.
# Added details for 4020154313.
# Added details for 4020154319.
# Added details for 4020154388.
# Added details for 4020154392.
# Added details for 4020154425.
# Added details for 4020154531.
# Added details for 4020154552.
# Added details for 4020154569.
# Added details for 4020154605.
# Added details for 4020155002.
# Added details for 4020155030.
# Added details for 4020155034.
# Added details for 4020155086.
# Added details for 4020155281.
# Added details for 4020155338.
# Added details for 4020155339.
# Added details for 4020155512.
# Added details for 4020155547.
# Added details for 4020155555.
# Added details for 4020155576.
# Added details for 4020155584.
# Added details for 4020155660.
# Added details for 4020155686.
# Added details for 4020155844.
# Added details for 4020155852.
# Added details for 4020156109.
# Added details for 4020156219.
# Added details for 4020156281.
# Added details for 4020156353.
# Added details for 4020156445.
# Added details for 4020156550.
# Added details for 4020156613.
# Added details for 4020156626.
# Added details for 4020156664.
# Added details for 4020156839.
# Added details for 4020156953.
# Added details for 4020157042.
# Added details for 4020157071.
# Added details for 4020157160.
# Added details for 4020157250.
# Added details for 4020157483.
# Added details for 4020157676.
# Added details for 4020157839.
# Added details for 4020157881.
# Added details for 4020157934.
# Added details for 4020158003.
# Added details for 4020158441.
# Added details for 4020158508.
# Added details for 4020158609.
# Added details for 4020158911.
# Added details for 4020159005.
# Added details for 4020159041.
# Added details for 4020159084.
# Added details for 4020159165.
# Added details for 4020159190.
# Added details for 4020159196.
# Added details for 4020159274.
# Added details for 4020159382.
# Added details for 4020159430.
# Added details for 4020159461.
# Added details for 4020159571.
# Added details for 4020159789.
# Added details for 4020159798.
# Added details for 4020159893.
# Added details for 4020159910.
# Added details for 4020159934.
# Added details for 4020160106.
# Added details for 4020160119.
# Added details for 4020160153.
# Added details for 4020160297.
# Added details for 4020160411.
# Added details for 4020160470.
# Added details for 4020160479.
# Added details for 4020160555.
# Added details for 4020160657.
# Added details for 4020160871.
# Added details for 4020160966.
# Added details for 4020161136.
# Added details for 4020161324.
# Added details for 4020161334.
# Added details for 4020161388.
# Added details for 4020161428.
# Added details for 4020161467.
# Added details for 4020161510.
# Added details for 4020161585.
# Added details for 4020161687.
# Added details for 4020161723.
# Added details for 4020161970.
# Added details for 4020162081.
# Added details for 4020162179.
# Added details for 4020162342.
# Added details for 4020162515.
# Added details for 4020162560.
# Added details for 4020162586.
# Added details for 4020162640.
# Added details for 4020162701.
# Added details for 4020162719.
# Added details for 4020162743.
# Added details for 4020162755.
# Added details for 4020162897.
# Added details for 4020163261.
# Added details for 4020163265.
# Added details for 4020163367.
# Added details for 4020163429.
# Added details for 4020163521.
# Added details for 4020163558.
# Added details for 4020163648.
# Added details for 4020163757.
# Added details for 4020163855.
# Added details for 4020163889.
# Added details for 4020164043.
# Added details for 4020164078.
# Added details for 4020164143.
# Added details for 4020164204.
# Added details for 4020164288.
# Added details for 4020164306.
# Added details for 4020164637.
# Added details for 4020164746.
# Added details for 4020164880.
# Added details for 4020164888.
# Added details for 4020165109.
# Added details for 4020165298.
# Added details for 4020165376.
# Added details for 4020165392.
# Added details for 4020165631.
# Added details for 4020165745.
# Added details for 4020165859.
# Added details for 4020165972.
# Added details for 4020166188.
# Added details for 4020166233.
# Added details for 4020166312.
# Added details for 4020166496.
# Added details for 4020166860.
# Added details for 4020166904.
# Added details for 4020166975.
# Added details for 4020167045.
# Added details for 4020167123.
# Added details for 4020167160.
# Added details for 4020167309.
# Added details for 4020167564.
# Added details for 4020167566.
# Added details for 4020167625.
# Added details for 4020167818.
# Added details for 4020167847.
# Added details for 4020167915.
# Added details for 4020168268.
# Added details for 4020168293.
# Added details for 4020168300.
# Added details for 4020168529.
# Added details for 4020168939.
# Added details for 4020169047.
# Added details for 4020169180.
# Added details for 4020169319.
# Added details for 4020169406.
# Added details for 4020169580.
# Added details for 4020169797.
# Added details for 4020169811.
# Added details for 4020169870.
# Added details for 4020169917.
# Added details for 4020170144.
# Added details for 4020170381.
# Added details for 4020170553.
# Added details for 4020170654.
# Added details for 4020170996.
# Added details for 4020171010.
# Added details for 4020171095.
# Added details for 4020171113.
# Added details for 4020171134.
# Added details for 4020171179.
# Added details for 4020171217.
# Added details for 4020171263.
# Added details for 4020171379.
# Added details for 4020171492.
# Added details for 4020171516.
# Added details for 4020171561.
# Added details for 4020171592.
# Added details for 4020171671.
# Added details for 4020171724.
# Added details for 4020171918.
# Added details for 4020172051.
# Added details for 4020172070.
# Added details for 4020172446.
# Added details for 4020172533.
# Added details for 4020172605.
# Added details for 4020172611.
# Added details for 4020172662.
# Added details for 4020172769.
# Added details for 4020172818.
# Added details for 4020172914.
# Added details for 4020172916.
# Added details for 4020173084.
# Added details for 4020173197.
# Added details for 4020173198.
# Added details for 4020173249.
# Added details for 4020173325.
# Added details for 4020173403.
# Added details for 4020173441.
# Added details for 4020173523.
# Added details for 4020173692.
# Added details for 4020173907.
# Added details for 4020173986.
# Added details for 4020174001.
# Added details for 4020174005.
# Added details for 4020174278.
# Added details for 4020174300.
# Added details for 4020174321.
# Added details for 4020174446.
# Added details for 4020174522.
# Added details for 4020174535.
# Added details for 4020174588.
# Added details for 4020174676.
# Added details for 4020174687.
# Added details for 4020174978.
# Added details for 4020174990.
# Added details for 4020175098.
# Added details for 4020175152.
# Added details for 4020175172.
# Added details for 4020175180.
# Added details for 4020175295.
# Added details for 4020175408.
# Added details for 4020175547.
# Added details for 4020175621.
# Added details for 4020175623.
# Added details for 4020175835.
# Added details for 4020175857.
# Added details for 4020175911.
# Added details for 4020175927.
# Added details for 4020176022.
# Added details for 4020176301.
# Added details for 4020176351.
# Added details for 4020176356.
# Added details for 4020176726.
# Added details for 4020176750.
# Added details for 4020176798.
# Added details for 4020176939.
# Added details for 4020177011.
# Added details for 4020177061.
# Added details for 4020177238.
# Added details for 4020177242.
# Added details for 4020177246.
# Added details for 4020177259.
# Added details for 4020177329.
# Added details for 4020177364.
# Added details for 4020177384.
# Added details for 4020177399.
# Added details for 4020177652.
# Added details for 4020177678.
# Added details for 4020177747.
# Added details for 4020177937.
# Added details for 4020178162.
# Added details for 4020178336.
# Added details for 4020178379.
# Added details for 4020178520.
# Added details for 4020178564.
# Added details for 4020178625.
# Added details for 4020178859.
# Added details for 4020179100.
# Added details for 4020179113.
# Added details for 4020179223.
# Added details for 4020179352.
# Added details for 4020179412.
# Added details for 4020179464.
# Added details for 4020179491.
# Added details for 4020179496.
# Added details for 4020179796.
# Added details for 4020180041.
# Added details for 4020180084.
# Added details for 4020180193.
# Added details for 4020180365.
# Added details for 4020180409.
# Added details for 4020180724.
# Added details for 4020180774.
# Added details for 4020180803.
# Added details for 4020180851.
# Added details for 4020180858.
# Added details for 4020180882.
# Added details for 4020181043.
# Added details for 4020181155.
# Added details for 4020181376.
# Added details for 4020181521.
# Added details for 4020181526.
# Added details for 4020181564.
# Added details for 4020181595.
# Added details for 4020181735.
# Added details for 4020181774.
# Added details for 4020181785.
# Added details for 4020181797.
# Added details for 4020181907.
# Added details for 4020181919.
# Added details for 4020181960.
# Added details for 4020182050.
# Added details for 4020182303.
# Added details for 4020182484.
# Added details for 4020182507.
# Added details for 4020182536.
# Added details for 4020182735.
# Added details for 4020182933.
# Added details for 4020183094.
# Added details for 4020183158.
# Added details for 4020183173.
# Added details for 4020183195.
# Added details for 4020183231.
# Added details for 4020183241.
# Added details for 4020183469.
# Added details for 4020183492.
# Added details for 4020183498.
# Added details for 4020183602.
# Added details for 4020183737.
# Added details for 4020183854.
# Added details for 4020183989.
# Added details for 4020184134.
# Added details for 4020184240.
# Added details for 4020184296.
# Added details for 4020184314.
# Added details for 4020184337.
# Added details for 4020184350.
# Added details for 4020184409.
# Added details for 4020184534.
# Added details for 4020184646.
# Added details for 4020184687.
# Added details for 4020184701.
# Added details for 4020184857.
# Added details for 4020184995.
# Added details for 4020185096.
# Added details for 4020185350.
# Added details for 4020185411.
# Added details for 4020185455.
# Added details for 4020185488.
# Added details for 4020185518.
# Added details for 4020185527.
# Added details for 4020185538.
# Added details for 4020185618.
# Added details for 4020185638.
# Added details for 4020185677.
# Added details for 4020185718.
# Added details for 4020185735.
# Added details for 4020185756.
# Added details for 4020185892.
# Added details for 4020185899.
# Added details for 4020185925.
# Added details for 4020185966.
# Added details for 4020186057.
# Added details for 4020186127.
# Added details for 4020186149.
# Added details for 4020186162.
# Added details for 4020186211.
# Added details for 4020186399.
# Added details for 4020186445.
# Added details for 4020186542.
# Added details for 4020186761.
# Added details for 4020186869.
# Added details for 4020186928.
# Added details for 4020187031.
# Added details for 4020187206.
# Added details for 4020187432.
# Added details for 4020187538.
# Added details for 4020187564.
# Added details for 4020187586.
# Added details for 4020187590.
# Added details for 4020187696.
# Added details for 4020187704.
# Added details for 4020187708.
# Added details for 4020187718.
# Added details for 4020187805.
# Added details for 4020188264.
# Added details for 4020188558.
# Added details for 4020188996.
# Added details for 4020189055.
# Added details for 4020189130.
# Added details for 4020189146.
# Added details for 4020189164.
# Added details for 4020189318.
# Added details for 4020189382.
# Added details for 4020189460.
# Added details for 4020189798.
# Added details for 4020189900.
# Added details for 4020189942.
# Added details for 4020190075.
# Added details for 4020190171.
# Added details for 4020190199.
# Added details for 4020190224.
# Added details for 4020190243.
# Added details for 4020190427.
# Added details for 4020190673.
# Added details for 4020190778.
# Added details for 4020191113.
# Added details for 4020191152.
# Added details for 4020191429.
# Added details for 4020191578.
# Added details for 4020191691.
# Added details for 4020191831.
# Added details for 4020192036.
# Added details for 4020192098.
# Added details for 4020192273.
# Added details for 4020192317.
# Added details for 4020192433.
# Added details for 4020192508.
# Added details for 4020192567.
# Added details for 4020192574.
# Added details for 4020192619.
# Added details for 4020192648.
# Added details for 4020192819.
# Added details for 4020192910.
# Added details for 4020192911.
# Added details for 4020192918.
# Added details for 4020192999.
# Added details for 4020193002.
# Added details for 4020193088.
# Added details for 4020193114.
# Added details for 4020193135.
# Added details for 4020193313.
# Added details for 4020193511.
# Added details for 4020193528.
# Added details for 4020193537.
# Added details for 4020193816.
# Added details for 4020193879.
# Added details for 4020193972.
# Added details for 4020193994.
# Added details for 4020194222.
# Added details for 4020194377.
# Added details for 4020194542.
# Added details for 4020194593.
# Added details for 4020194612.
# Added details for 4020194705.
# Added details for 4020195143.
# Added details for 4020195148.
# Added details for 4020195239.
# Added details for 4020195466.
# Added details for 4020195662.
# Added details for 4020195666.
# Added details for 4020195709.
# Added details for 4020196009.
# Added details for 4020196150.
# Added details for 4020196163.
# Added details for 4020196202.
# Added details for 4020196210.
# Added details for 4020196306.
# Added details for 4020196353.
# Added details for 4020196724.
# Added details for 4020196870.
# Added details for 4020196950.
# Added details for 4020197117.
# Added details for 4020197249.
# Added details for 4020197348.
# Added details for 4020197506.
# Added details for 4020197509.
# Added details for 4020197850.
# Added details for 4020197893.
# Added details for 4020198031.
# Added details for 4020198110.
# Added details for 4020198252.
# Added details for 4020198259.
# Added details for 4020198307.
# Added details for 4020198531.
# Added details for 4020198602.
# Added details for 4020198674.
# Added details for 4020198780.
# Added details for 4020198904.
# Added details for 4020199032.
# Added details for 4020199041.
# Added details for 4020199076.
# Added details for 4020199166.
# Added details for 4020199476.
# Added details for 4020199536.
# Added details for 4020199571.
# Added details for 4020199616.
# Added details for 4020199649.
# Added details for 4020199716.
# Added details for 4020199804.
# Added details for 4020200035.
# Added details for 4020200161.
# Added details for 4020200213.
# Added details for 4020200301.
# Added details for 4020200429.
# Added details for 4020200436.
# Added details for 4020200534.
# Added details for 4020200561.
# Added details for 4020200631.
# Added details for 4020200749.
# Added details for 4020201021.
# Added details for 4020201066.
# Added details for 4020201230.
# Added details for 4020201343.
# Added details for 4020201919.
# Added details for 4020201960.
# Added details for 4020201962.
# Added details for 4020202053.
# Added details for 4020202148.
# Added details for 4020202172.
# Added details for 4020202218.
# Added details for 4020202243.
# Added details for 4020202280.
# Added details for 4020202447.
# Added details for 4020202580.
# Added details for 4020202828.
# Added details for 4020202840.
# Added details for 4020202977.
# Added details for 4020203235.
# Added details for 4020203292.
# Added details for 4020203361.
# Added details for 4020203405.
# Added details for 4020203422.
# Added details for 4020203465.
# Added details for 4020203632.
# Added details for 4020203866.
# Added details for 4020203882.
# Added details for 4020203978.
# Added details for 4020204022.
# Added details for 4020204161.
# Added details for 4020204231.
# Added details for 4020204317.
# Added details for 4020204451.
# Added details for 4020204552.
# Added details for 4020204565.
# Added details for 4020204816.
# Added details for 4020204839.
# Added details for 4020204889.
# Added details for 4020204991.
# Added details for 4020205002.
# Added details for 4020205089.
# Added details for 4020205262.
# Added details for 4020205503.
# Added details for 4020205657.
# Added details for 4020205719.
# Added details for 4020205732.
# Added details for 4020205776.
# Added details for 4020206017.
# Added details for 4020206210.
# Added details for 4020206274.
# Added details for 4020206301.
# Added details for 4020206342.
# Added details for 4020206455.
# Added details for 4020206517.
# Added details for 4020206608.
# Added details for 4020206619.
# Added details for 4020206879.
# Added details for 4020207095.
# Added details for 4020207221.
# Added details for 4020207410.
# Added details for 4020207519.
# Added details for 4020207557.
# Added details for 4020207576.
# Added details for 4020207614.
# Added details for 4020207652.
# Added details for 4020207729.
# Added details for 4020207821.
# Added details for 4020208009.
# Added details for 4020208250.
# Added details for 4020208254.
# Added details for 4020208256.
# Added details for 4020208339.
# Added details for 4020208378.
# Added details for 4020208433.
# Added details for 4020208488.
# Added details for 4020208749.
# Added details for 4020208944.
# Added details for 4020209051.
# Added details for 4020209096.
# Added details for 4020209104.
# Added details for 4020209134.
# Added details for 4020209326.
# Added details for 4020209363.
# Added details for 4020209425.
# Added details for 4020209529.
# Added details for 4020209599.
# Added details for 4020209657.
# Added details for 4020209658.
# Added details for 4020209679.
# Added details for 4020210014.
# Added details for 4020210228.
# Added details for 4020210339.
# Added details for 4020210392.
# Added details for 4020210423.
# Added details for 4020210424.
# Added details for 4020210465.
# Added details for 4020210513.
# Added details for 4020210779.
# Added details for 4020210856.
# Added details for 4020210939.
# Added details for 4020211099.
# Added details for 4020211101.
# Added details for 4020211262.
# Added details for 4020211501.
# Added details for 4020211506.
# Added details for 4020211569.
# Added details for 4020211571.
# Added details for 4020211619.
# Added details for 4020211643.
# Added details for 4020211683.
# Added details for 4020211686.
# Added details for 4020211706.
# Added details for 4020211882.
# Added details for 4020211959.
# Added details for 4020212062.
# Added details for 4020212448.
# Added details for 4020212465.
# Added details for 4020212756.
# Added details for 4020213194.
# Added details for 4020213245.
# Added details for 4020213306.
# Added details for 4020213433.
# Added details for 4020213608.
# Added details for 4020213633.
# Added details for 4020213851.
# Added details for 4020214041.
# Added details for 4020214367.
# Added details for 4020214401.
# Added details for 4020214416.
# Added details for 4020214528.
# Added details for 4020214579.
# Added details for 4020214811.
# Added details for 4020214933.
# Added details for 4020215063.
# Added details for 4020215159.
# Added details for 4020215163.
# Added details for 4020215165.
# Added details for 4020215182.
# Added details for 4020215218.
# Added details for 4020215220.
# Added details for 4020215481.
# Added details for 4020215522.
# Added details for 4020215583.
# Added details for 4020215661.
# Added details for 4020215683.
# Added details for 4020215732.
# Added details for 4020215844.
# Added details for 4020215992.
# Added details for 4020216108.
# Added details for 4020216173.
# Added details for 4020216461.
# Added details for 4020216483.
# Added details for 4020216657.
# Added details for 4020216690.
# Added details for 4020216769.
# Added details for 4020216900.
# Added details for 4020216976.
# Added details for 4020217002.
# Added details for 4020217071.
# Added details for 4020217143.
# Added details for 4020217372.
# Added details for 4020217425.
# Added details for 4020217646.
# Added details for 4020217760.
# Added details for 4020217968.
# Added details for 4020218465.
# Added details for 4020218519.
# Added details for 4020218576.
# Added details for 4020218715.
# Added details for 4020218902.
# Added details for 4020218965.
# Added details for 4020218968.
# Added details for 4020219398.
# Added details for 4020219472.
# Added details for 4020219623.
# Added details for 4020219750.
# Added details for 4020219826.
# Added details for 4020219837.
# Added details for 4020219853.
# Added details for 4020219891.
# Added details for 4020220150.
# Added details for 4020220213.
# Added details for 4020220246.
# Added details for 4020220504.
# Added details for 4020221138.
# Added details for 4020221322.
# Added details for 4020221582.
# Added details for 4020221638.
# Added details for 4020221791.
# Added details for 4020221827.
# Added details for 4020221895.
# Added details for 4020221913.
# Added details for 4020221972.
# Added details for 4020222006.
# Added details for 4020222042.
# Added details for 4020222085.
# Added details for 4020222231.
# Added details for 4020222266.
# Added details for 4020222387.
# Added details for 4020222456.
# Added details for 4020222508.
# Added details for 4020222589.
# Added details for 4020222702.
# Added details for 4020222826.
# Added details for 4020222926.
# Added details for 4020222998.
# Added details for 4020223010.
# Added details for 4020223132.
# Added details for 4020223192.
# Added details for 4020223251.
# Added details for 4020223269.
# Added details for 4020223380.
# Added details for 4020223460.
# Added details for 4020223533.
# Added details for 4020223795.
# Added details for 4020223850.
# Added details for 4020223982.
# Added details for 4020224070.
# Added details for 4020224308.
# Added details for 4020224348.
# Added details for 4020224462.
# Added details for 4020224499.
# Added details for 4020224548.
# Added details for 4020224702.
# Added details for 4020224711.
# Added details for 4020224840.
# Added details for 4020225043.
# Added details for 4020225097.
# Added details for 4020225126.
# Added details for 4020225255.
# Added details for 4020225332.
# Added details for 4020225442.
# Added details for 4020225522.
# Added details for 4020225643.
# Added details for 4020225765.
# Added details for 4020225861.
# Added details for 4020226012.
# Added details for 4020226033.
# Added details for 4020226034.
# Added details for 4020226204.
# Added details for 4020226284.
# Added details for 4020226295.
# Added details for 4020226344.
# Added details for 4020226369.
# Added details for 4020226412.
# Added details for 4020226495.
# Added details for 4020226527.
# Added details for 4020226559.
# Added details for 4020226683.
# Added details for 4020226792.
# Added details for 4020227284.
# Added details for 4020227480.
# Added details for 4020227547.
# Added details for 4020227639.
# Added details for 4020227794.
# Added details for 4020227804.
# Added details for 4020227827.
# Added details for 4020228009.
# Added details for 4020228283.
# Added details for 4020228325.
# Added details for 4020228400.
# Added details for 4020229019.
# Added details for 4020229071.
# Added details for 4020229087.
# Added details for 4020229192.
# Added details for 4020229396.
# Added details for 4020229446.
# Added details for 4020229447.
# Added details for 4020229495.
# Added details for 4020229658.
# Added details for 4020229665.
# Added details for 4020229713.
# Added details for 4020229878.
# Added details for 4020230018.
# Added details for 4020230041.
# Added details for 4020230099.
# Added details for 4020230278.
# Added details for 4020230724.
# Added details for 4020230868.
# Added details for 4020231132.
# Added details for 4020231242.
# Added details for 4020231356.
# Added details for 4020231574.
# Added details for 4020231746.
# Added details for 4020232003.
# Added details for 4020232423.
# Added details for 4020232570.
# Added details for 4020232732.
# Added details for 4020232739.
# Added details for 4020233584.
# Added details for 4020233656.
# Added details for 4020234438.
# Added details for 4020235013.
# Added details for 4020235202.
# Added details for 4020235248.
# Added details for 4020235782.
# Added details for 4020236092.
# Added details for 4020236452.
# Added details for 4020238096.
# Added details for 4020238276.
# Added details for 4020238337.
# Added details for 4020238476.
# Added details for 4020238527.
# Added details for 4020238583.
# Added details for 4020239573.
# Added details for 4020241548.
# Added details for 4020242512.
# Added details for 4020242723.
# Added details for 4020243946.
# Added details for 4020250866.
# Added details for 4020255790.
# Added details for 4020257045.
# Inside match_details
# Inside do_match_details
# Inside match_details

# %%
# match_history_thread = Thread(target=match_history)
# match_history_thread.daemon = True
# match_details_thread = Thread(target=match_details)
# match_details_thread.daemon = True
# match_history_thread.start()
# match_details_thread.start()
# Out:
# Inside do_match_details
# Inside match_details
# Inside do_match_details
# Added details for 4020619635.
# Added details for 4020619645.
# Added details for 4020619670.
# Added details for 4020619706.
# Added details for 4020619782.
# Added details for 4020619849.
# Added details for 4020620010.
# Added details for 4020620023.
# Added details for 4020620038.
# Added details for 4020620040.
# Added details for 4020620169.
# Added details for 4020620175.
# Added details for 4020620823.
# Added details for 4020620965.
# Added details for 4020620983.
# Added details for 4020621132.
# Added details for 4020621619.
# Added details for 4020621625.
# Added details for 4020621769.
# Added details for 4020621812.
# Added details for 4020622011.
# Added details for 4020622062.
# Added details for 4020622112.
# Added details for 4020622368.
# Added details for 4020622400.
# Added details for 4020622898.
# Added details for 4020622975.
# Added details for 4020623070.
# Added details for 4020623329.
# Added details for 4020623356.
# Added details for 4020623359.
# Added details for 4020623583.
# Added details for 4020623675.
# Added details for 4020623763.
# Added details for 4020623769.
# Added details for 4020623853.
# Added details for 4020624091.
# Added details for 4020624113.
# Added details for 4020624281.
# Added details for 4020624621.
# Added details for 4020624680.
# Added details for 4020624697.
# Added details for 4020624866.
# Added details for 4020625337.
# Added details for 4020625426.
# Added details for 4020625504.
# Added details for 4020625522.
# Added details for 4020625552.
# Added details for 4020625856.
# Added details for 4020625984.
# Added details for 4020626577.
# Added details for 4020626968.
# Added details for 4020627048.
# Added details for 4020627080.
# WARNING:root:Api or timeout error in MatchDetails on matchid 4020627124.
# Added details for 4020627156.
# Added details for 4020627234.
# Added details for 4020627258.
# Added details for 4020627378.
# Added details for 4020627794.
# Added details for 4020628013.
# Added details for 4020628220.
# Added details for 4020628572.
# Added details for 4020628908.
# Added details for 4020629115.
# Added details for 4020629728.
# Added details for 4020629807.
# Added details for 4020630138.
# Added details for 4020630349.
# Added details for 4020630477.
# Added details for 4020630622.
# Added details for 4020630721.
# Added details for 4020630892.
# Added details for 4020630989.
# Added details for 4020631124.
# Added details for 4020631220.
# Added details for 4020631324.
# Added details for 4020631885.
# Added details for 4020631900.
# Added details for 4020632490.
# Added details for 4020632739.
# Added details for 4020633129.
# Added details for 4020633603.
# Added details for 4020633671.
# Added details for 4020634255.
# Added details for 4020634558.
# Added details for 4020634807.
# Added details for 4020634827.
# Added details for 4020635365.
# Added details for 4020635444.
# Added details for 4020635662.
# Added details for 4020635985.
# Added details for 4020636121.
# Added details for 4020636380.
# Added details for 4020637686.
# Added details for 4020637907.
# Added details for 4020638022.
# Added details for 4020638064.
# Added details for 4020638773.
# Added details for 4020638834.
# Added details for 4020638910.
# Added details for 4020640444.
# Added details for 4020641233.
# Added details for 4020641354.
# Added details for 4020642431.
# Added details for 4020642938.
# Added details for 4020646478.
# Added details for 4020647073.
# Added details for 4020647905.
# Added details for 4020653987.
# Added details for 4020655081.
# Added details for 4020658786.
# Added details for 4020660482.
# Inside match_details
